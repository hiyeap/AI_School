# %%
import os
file_names=os.listdir('C:/Users/smhrd/DeepStudy/bikenum_label1/train/labels')

# %%
file_names[1]
# Out:
# '------6815_jpg.rf.3254c441f83abcc9ace67f41a366070c.txt'

# %%
text_file_path = 'C:/Users/smhrd/DeepStudy/bikenum_label1/train/labels/'+ file_names[1]

# %%
text_file_path
# Out:
# 'C:/Users/smhrd/DeepStudy/bikenum_label1/train/labels/------6815_jpg.rf.3254c441f83abcc9ace67f41a366070c.txt'

# %%
k=0
for i in file_names:
    text_file_path = 'C:/Users/smhrd/DeepStudy/bikenum_label1/train/labels/'+ file_names[k]
    with open(text_file_path,'r') as f:
        lines = f.readlines()
        print(lines[0][0])
    with open(text_file_path,'w') as f:
        f.write(lines[0].replace('2','1',1))
    k = k+1
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
