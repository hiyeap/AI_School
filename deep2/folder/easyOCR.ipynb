# %%
# !pip install opencv-python==4.5.4.60 easyocr
# Out:
# ...
#   Using cached easyocr-1.4.2-py3-none-any.whl (70.8 MB)
# ...
#   Using cached python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# ...

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
# !pip install cvlib
# Out:
# ...
#   Using cached cvlib-0.2.7.tar.gz (13.1 MB)
# ...
#   Using cached progressbar-2.5.tar.gz (10 kB)
# ...
#   Using cached imutils-0.5.4.tar.gz (17 kB)
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.7-py3-none-any.whl size=10046385 sha256=482b34ae9cb9d2832a7c459bfae9c967aa90a99bc525cbc1db9c4795504dc0ef
#   Stored in directory: c:\users\smhrd\appdata\local\pip\cache\wheels\bb\11\55\82ced947752cc4056335a4ee9c304a93d43ce857230538f0ae
# ...
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25872 sha256=f9f98ed0a91ea6689579100f28e0377e9ed722f1266368404234d82ff3ea6849
#   Stored in directory: c:\users\smhrd\appdata\local\pip\cache\wheels\59\1b\52\0dea905f8278d5514dc4d0be5e251967f8681670cadd3dca89
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12082 sha256=6befa7b6fadb08a464cbb72b032b23c1451434522cfa6163793d202415398d64
#   Stored in directory: c:\users\smhrd\appdata\local\pip\cache\wheels\2c\67\ed\d84123843c937d7e7f5ba88a270d11036473144143355e2747
# ...

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("./bike/0679.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.xticks([]), plt.yticks([])
plt.imshow(img)
plt.show()

import cvlib as cv
from cvlib.object_detection import draw_bbox

# yolov3를 이용해서 객체 탐지 및 인식
# 객체의 영역, 객체의 라벨, 정확도를 반환
# confidence : 정확도 (인식이 잘 안되면 값을 작게 설정)
bbox, label, conf = cv.detect_common_objects(img,
                                             confidence = 0.3,
                                             model = "yolov3")
img2 = draw_bbox(img, bbox, label, conf)

plt.xticks([]), plt.yticks([])
plt.imshow(img2)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("./bike/num.jfif")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.xticks([]), plt.yticks([])
plt.imshow(img)
plt.show()

import cvlib as cv
from cvlib.object_detection import draw_bbox

# yolov3를 이용해서 객체 탐지 및 인식
# 객체의 영역, 객체의 라벨, 정확도를 반환
# confidence : 정확도 (인식이 잘 안되면 값을 작게 설정)
bbox, label, conf = cv.detect_common_objects(img,
                                             confidence = 0.3,
                                             model = "yolov3")
img2 = draw_bbox(img, bbox, label, conf)

plt.xticks([]), plt.yticks([])
plt.imshow(img2)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("./bike/num2.jfif")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.xticks([]), plt.yticks([])
plt.imshow(img)
plt.show()

import cvlib as cv
from cvlib.object_detection import draw_bbox

# yolov3를 이용해서 객체 탐지 및 인식
# 객체의 영역, 객체의 라벨, 정확도를 반환
# confidence : 정확도 (인식이 잘 안되면 값을 작게 설정)
bbox, label, conf = cv.detect_common_objects(img,
                                             confidence = 0.2,
                                             model = "yolov3")
img2 = draw_bbox(img, bbox, label, conf)

plt.xticks([]), plt.yticks([])
plt.imshow(img2)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("./bike/num5.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.xticks([]), plt.yticks([])
plt.imshow(img)
plt.show()

import cvlib as cv
from cvlib.object_detection import draw_bbox

# yolov3를 이용해서 객체 탐지 및 인식
# 객체의 영역, 객체의 라벨, 정확도를 반환
# confidence : 정확도 (인식이 잘 안되면 값을 작게 설정)
bbox, label, conf = cv.detect_common_objects(img,
                                             confidence = 0.1,
                                             model = "yolov3")
img2 = draw_bbox(img, bbox, label, conf)

plt.xticks([]), plt.yticks([])
plt.imshow(img2)
plt.show()

# %%
import easyocr
reader = easyocr.Reader(['ko', 'en']) 
result = reader.readtext('./data/test/0679_jpg.rf.615f3dc00fea8b6ac9ad0da16f63c74d.jpg') 
print(result)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# []

# %%
reader = easyocr.Reader(['ko', 'en']) 
result = reader.readtext('./data/test/160_jpg.rf.e3c544020e6a7a8c35299feb03b76516.jpg') 
print(result)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[12, 14], [64, 14], [64, 96], [12, 96]], '하', 0.5584701613747853)]

# %%
reader = easyocr.Reader(['ko', 'en']) 
result = reader.readtext('./data/test/18_jpg.rf.4f721c238b855275b3dad649496fb479.jpg') 
print(result)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[3, 15], [65, 15], [65, 95], [3, 95]], '바', 0.4337242473341121)]

# %%
reader = easyocr.Reader(['ko', 'en']) 
result = reader.readtext('./data/test/19_jpg.rf.bd11e841abadb514b9c384906ad14c7f.jpg') 
print(result)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# []

# %%
reader = easyocr.Reader(['ko', 'en']) 
result = reader.readtext('./data/test/460_png.rf.34f0b2571c0105f6beed7b3a6f07abee.jpg') 
print(result)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# []

# %%
reader = easyocr.Reader(['ko', 'en']) 
result = reader.readtext('./data/test/482_jpg.rf.b9b6a7e107e5cb4572ce1998daf41875.jpg') 
print(result)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# []

# %%
# 경기부천 카 0130
reader = easyocr.Reader(['ko', 'en']) 
result = reader.readtext('./Bikenum/train/images/-----0130_jpg.rf.274b35fd99c5ff67fefb59795ed3a654.jpg') 
print(result)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[119, 172], [347, 172], [347, 293], [119, 293]], '0130', 0.45266902446746826)]

# %%
# 경기부천 차 0155
reader = easyocr.Reader(['ko', 'en']) 
result = reader.readtext('./Bikenum/train/images/-----0155_jpg.rf.7d808324d13258373e4cdd3ba20e0658.jpg') 
print(result)
result[0] = list(result[0])
result[0][1]="경기부천"
result[1] = list(result[1])
result[1][1]="차0155"
print(result)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[158, 138], [300, 138], [300, 190], [158, 190]], 'VIIV ?', 0.175109503899806), ([[101, 181], [313, 181], [313, 271], [101, 271]], '10155', 0.6737839848364864)]
# [[[[158, 138], [300, 138], [300, 190], [158, 190]], '경기부천', 0.175109503899806], [[[101, 181], [313, 181], [313, 271], [101, 271]], '차0155', 0.6737839848364864]]

# %%
# 경기부천 카 0182
reader = easyocr.Reader(['ko', 'en']) 
result = reader.readtext('./Bikenum/train/images/-----0182_jpg.rf.280f55e4e55c9aff3d00ec75a1f4eb0c.jpg') 
print(result)
result[0] = list(result[0])
result[0][1]="경기부천"
result[1] = list(result[1])
result[1][1]="카0182"
print(result)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[125, 89], [307, 89], [307, 177], [125, 177]], '경기부전', 0.1793244630098343), ([[44, 168], [368, 168], [368, 321], [44, 321]], '(카0182', 0.24970694068184432)]
# [[[[125, 89], [307, 89], [307, 177], [125, 177]], '경기부천', 0.1793244630098343], [[[44, 168], [368, 168], [368, 321], [44, 321]], '카0182', 0.24970694068184432]]

# %%
# 경기부천 카 0184
reader = easyocr.Reader(['ko', 'en']) 
result = reader.readtext('./Bikenum/train/images/-----0184-2_jpg.rf.59b1bc4a9f57935d2a04369bab9165d5.jpg') 
print(result)
result[0] = list(result[0])
result[0][1]="경기부천"
result[1] = list(result[1])
result[1][1]="카0184"
print(result)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[141, 127], [291, 127], [291, 189], [141, 189]], '권기무진', 0.28907719254493713), ([[76, 182], [332, 182], [332, 282], [76, 282]], '170184', 0.6782122034862053)]
# [[[[141, 127], [291, 127], [291, 189], [141, 189]], '경기부천', 0.28907719254493713], [[[76, 182], [332, 182], [332, 282], [76, 282]], '카0184', 0.6782122034862053]]

# %%
# 경기부천 차 0188
reader = easyocr.Reader(['ko', 'en']) 
result = reader.readtext('./Bikenum/train/images/-----0188_jpg.rf.cc54555ce08974b32ad75028af2ccd9b.jpg') 
print(result)
result[0] = list(result[0])
result[0][1]="경기부천"
result[1] = list(result[1])
result[1][1]="차0188"
print(result)
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[124, 106], [294, 106], [294, 184], [124, 184]], '경기무전', 0.5966185927391052), ([[58, 169], [351, 169], [351, 310], [58, 310]], '(차0188', 0.4902275213504699)]
# [[[[124, 106], [294, 106], [294, 184], [124, 184]], '경기부천', 0.5966185927391052], [[[58, 169], [351, 169], [351, 310], [58, 310]], '차0188', 0.4902275213504699]]
