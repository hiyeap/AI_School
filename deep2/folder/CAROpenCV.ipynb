# %% [markdown]
# ### OCR(광학문자판독)
# - 이미지로 된 문자를 텍스트로 변환하는 작업
# - Tessaract API, 구글 OCR API, Naver OCR API 등을 사용
# - https://github.com/UB-Mannheim/tesseract/wiki
# - Additional language data

# %%
# 파이썬용 Tessaract API 설치
# !pip install pytesseract
# Out:
# Collecting pytesseract
#   Using cached pytesseract-0.3.9-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\smhrd\anaconda3\envs\deep2\lib\site-packages (from pytesseract) (9.1.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\smhrd\anaconda3\envs\deep2\lib\site-packages (from pytesseract) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\smhrd\anaconda3\envs\deep2\lib\site-packages (from packaging>=21.3->pytesseract) (3.0.8)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.9

# %%
# 설치 위치를 지정
import pytesseract
pytesseract.pytesseract.tesseract_cmd = \
r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# 이미지 불러오기
img = cv2.imread("../data/car.jpg")
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

plt.xticks([])
plt.yticks([])
plt.imshow(img)

# %%
result = pytesseract.image_to_string(img, lang="kor")
print(result)
# Out:
# 렐 52 단 3108 를
# | 152 가 3018

# %% [markdown]
# - tesseract API 사용할 때는 이진 이미지로 변경한 후에 사용하는 것을 권장!

# %%
img = cv2.imread("../data/car.jpg")
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

# 흑백이미지로 변경
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 이진이미지로 변경
_, binary = cv2.threshold(gray, 128,255, cv2.THRESH_BINARY)

plt.xticks([])
plt.yticks([])
plt.imshow(binary, cmap="gray")

# %%
result = pytesseract.image_to_string(binary, lang="kor")
result
# Out:
# ':52갸3018\n'

# %%
img1 = cv2.imread("../data/car1.jfif")
img1 = cv2.cvtColor(img1, cv2.COLOR_RGB2BGR)

# 흑백이미지로 변경
gray = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

# 이진이미지로 변경
_, binary = cv2.threshold(gray, 200,255, cv2.THRESH_BINARY)

plt.xticks([])
plt.yticks([])
plt.imshow(binary, cmap="gray")

# %%
result = pytesseract.image_to_string(binary, lang="kor")
result
# Out:
# "…65 노 088'79\n\n5 995909898988088000000000000002\n"

# %%
img2 = cv2.imread("../data/car2.jfif")
img2 = cv2.cvtColor(img2, cv2.COLOR_RGB2BGR)

# 흑백이미지로 변경
gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# 이진이미지로 변경
_, binary = cv2.threshold(gray, 175,255, cv2.THRESH_BINARY)

plt.xticks([])
plt.yticks([])
plt.imshow(binary, cmap="gray")

# %%
result = pytesseract.image_to_string(binary, lang="kor")
result
# Out:
# "…65 노 088'79\n\n5 995909898988088000000000000002\n"

# %%
img3 = cv2.imread("./data/car3.jfif")
img3 = cv2.cvtColor(img3, cv2.COLOR_RGB2BGR)

# 흑백이미지로 변경
gray = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

# 이진이미지로 변경
_, binary = cv2.threshold(gray, 200,255, cv2.THRESH_BINARY)

plt.xticks([])
plt.yticks([])
plt.imshow(binary, cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12244\2429205963.py in <module>
#       1 img3 = cv2.imread("./data/car3.jfif")
# ----> 2 img3 = cv2.cvtColor(img3, cv2.COLOR_RGB2BGR)
#       3
#       4 # 흑백이미지로 변경
#       5 gray = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
#
# error: OpenCV(4.5.4) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
result = pytesseract.image_to_string(binary, lang="kor")
result

# %%
img4 = cv2.imread("./data/car4.jfif")
img4 = cv2.cvtColor(img4, cv2.COLOR_RGB2BGR)

# 흑백이미지로 변경
gray = cv2.cvtColor(img4, cv2.COLOR_BGR2GRAY)

# 이진이미지로 변경
_, binary = cv2.threshold(gray, 150,255, cv2.THRESH_BINARY)

plt.xticks([])
plt.yticks([])
plt.imshow(binary, cmap="gray")

# %%
result = pytesseract.image_to_string(binary, lang="kor")
result

# %%
img5 = cv2.imread("./data/car5.jfif")
img5 = cv2.cvtColor(img5, cv2.COLOR_RGB2BGR)

# 흑백이미지로 변경
gray = cv2.cvtColor(img5, cv2.COLOR_BGR2GRAY)

# 이진이미지로 변경
_, binary = cv2.threshold(gray, 150,255, cv2.THRESH_BINARY_INV)

plt.xticks([])
plt.yticks([])
plt.imshow(binary, cmap="gray")
result = pytesseract.image_to_string(binary, lang="kor")
result

# %% [markdown]
# ## 오토바이

# %%
img = cv2.imread("./data/num.jfif")
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

# 흑백이미지로 변경
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 이진이미지로 변경
_, binary = cv2.threshold(gray, 200,255, cv2.THRESH_BINARY)

plt.xticks([])
plt.yticks([])
plt.imshow(binary, cmap="gray")

# %%
result = pytesseract.image_to_string(binary, lang="kor")
result

# %%
img = cv2.imread("./data/num2.jfif")
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

# 흑백이미지로 변경
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 이진이미지로 변경
_, binary = cv2.threshold(gray, 210,255, cv2.THRESH_BINARY)

plt.xticks([])
plt.yticks([])
plt.imshow(binary, cmap="gray")
result = pytesseract.image_to_string(binary, lang="kor")
result

# %%
img = cv2.imread("./data/num3.jpg")
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

# 흑백이미지로 변경
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 이진이미지로 변경
_, binary = cv2.threshold(gray, 210,255, cv2.THRESH_BINARY)

plt.xticks([])
plt.yticks([])
plt.imshow(binary, cmap="gray")
result = pytesseract.image_to_string(binary, lang="kor")
result

# %%
img = cv2.imread("./data/num4.jpg")
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

# 흑백이미지로 변경
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 이진이미지로 변경
_, binary = cv2.threshold(gray, 210,255, cv2.THRESH_BINARY)

plt.xticks([])
plt.yticks([])
plt.imshow(binary, cmap="gray")
result = pytesseract.image_to_string(binary, lang="kor")
result

# %%
img = cv2.imread("./data/num5.jpg")
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

# 흑백이미지로 변경
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 이진이미지로 변경
_, binary = cv2.threshold(gray, 160,255, cv2.THRESH_BINARY)

plt.xticks([])
plt.yticks([])
plt.imshow(binary, cmap="gray")
result = pytesseract.image_to_string(binary, lang="kor")
result
