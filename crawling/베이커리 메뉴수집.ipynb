# %%
import requests as req
from bs4 import BeautifulSoup as bs

# %%
res = req.get("https://pcmap.place.naver.com/restaurant/1814898023/menu/list")
res.encoding = "utf-8-sig"
res.encoding
# Out:
# 'utf-8-sig'

# %%
soup = bs(res.text, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <title>네이버 플레이스</title>
# <meta charset="utf-8"/>
# <meta content="ie=edge" httpequiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no, shrink-to-fit=no viewport-fit=cover" id="_viewport" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://pcmap.place.naver.com/assets/shared/images/favicon-72.png" rel="icon" type="image/png"/>
# <link href="https://pcmap.place.naver.com/assets/shared/images/favicon-96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="https://pcmap.place.naver.com/assets/shared/images/favicon-144.png" rel="icon" sizes="144x144" type="image/png"/>
# <link href="https://pcmap.place.naver.com/assets/shared/images/favicon-192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="https://pcmap.place.naver.com/assets/shared/images/favicon-120.png" rel="apple-touch-icon"/>
# ...

# %%
menu = soup.select("._3yfZ1")
menu
# Out:
# [<span class="_3yfZ1">크로칸슈</span>,
#  <span class="_3yfZ1">크로칸볼</span>,
#  <span class="_3yfZ1">선물Box</span>,
#  <span class="_3yfZ1">에그타르트</span>,
#  <span class="_3yfZ1">크림치즈 마늘빵</span>,
#  <span class="_3yfZ1">팔미에르</span>,
#  <span class="_3yfZ1">클래식스콘</span>,
#  <span class="_3yfZ1">카카오스콘</span>,
#  <span class="_3yfZ1">그린티스콘</span>,
#  <span class="_3yfZ1">오레오크로와상</span>,
#  <span class="_3yfZ1">갈릭크로와상</span>,
#  <span class="_3yfZ1">플레인크로와상</span>,
#  <span class="_3yfZ1">커스터드크로와상</span>,
#  <span class="_3yfZ1">더티초코</span>,
#  <span class="_3yfZ1">애플파이</span>]

# %%
price = soup.select("._3qFuX")
price
# Out:
# [<div class="_3qFuX">2,800원</div>,
#  <div class="_3qFuX">2,600원</div>,
#  <div class="_3qFuX">1,000원</div>,
#  <div class="_3qFuX">2,800원</div>,
#  <div class="_3qFuX">2,600원</div>,
#  <div class="_3qFuX">2,800원</div>,
#  <div class="_3qFuX">3,200원</div>,
#  <div class="_3qFuX">3,200원</div>,
#  <div class="_3qFuX">3,200원</div>,
#  <div class="_3qFuX">3,700원</div>,
#  <div class="_3qFuX">3,700원</div>,
#  <div class="_3qFuX">3,000원</div>,
#  <div class="_3qFuX">3,500원</div>,
#  <div class="_3qFuX">3,700원</div>,
#  <div class="_3qFuX">2,400원</div>]

# %%
menuList = []
priceList = []
for i in range(len(menu)):
    menuList.append(menu[i].text)
    priceList.append(price[i].text)
dic = {"메뉴" : menuList, "가격" : priceList}

import pandas as pd
df = pd.DataFrame(dic)
df.to_csv("bs-bakery.csv", encoding="euc-kr")
