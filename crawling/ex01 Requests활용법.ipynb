# %%
# import 작업
# requests = 브라우저의 역할을 대신(요청, 응답정보를 처리)
import requests as req

# %%
# 1. 네이버 url을 통해서 사이트를 요청
# req야 네이버 페이지 좀 가져와줘!
# <Response [200]> = 통신에 성공했습니다.
res = req.get("https://www.naver.com/")

# %%
# 2. 응답받은 페이지에서 원하는 정보를 추출(카페, 블로그..)
res.text
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %% [markdown]
# ## beautifulSoup 라이브러리
# - 컴퓨터가 알아먹을 수 있는 언어 변형
#   - 응답받은 텍스트 데이터를 html데이터로 변형

# %%
# stoneSoup은 사용하지 않는다
from bs4 import BeautifulSoup as bs

# %%
# bs아 내가 가지고 있는 글자정보를 html정보로 바꿔줘~~
# bs("내가 가지고 있는 정보", "파싱방법")
soup = bs(res.text, "lxml")

# %%
# 네이버 페이지에서 카페, 블로그, 지식인.. 글자를 수집해!
# 데이터에서 a태그만 수집해줘~
data = soup.select("a.nav")
data
# Out:
# [<a class="nav" data-clk="svc.mail" href="https://mail.naver.com/"><i class="ico_mail"></i>메일</a>,
#  <a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">카페</a>,
#  <a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">블로그</a>,
#  <a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">지식iN</a>,
#  <a class="nav shop" data-clk="svc.shopping" href="https://shopping.naver.com/"><span class="blind">쇼핑</span></a>,
#  <a class="nav shoplive" data-clk="svc.shoppinglive" href="https://shoppinglive.naver.com/home"><span class="blind">쇼핑LIVE</span></a>,
#  <a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">Pay</a>,
#  <a class="nav" data-clk="svc.tvcast" href="https://tv.naver.com/"><i class="ico_tv"></i>TV</a>,
#  <a class="nav" data-clk="svc.dic" href="https://dict.naver.com/">사전</a>,
#  <a class="nav" data-clk="svc.news" href="https://news.naver.com/">뉴스</a>,
# ...

# %%
data[0].text
# Out:
# '메일'

# %%
for i in data:
    print(i.text)
# Out:
# 메일
# 카페
# 블로그
# 지식iN
# 쇼핑
# 쇼핑LIVE
# Pay
# TV
# 사전
# 뉴스
# 증권
# 부동산
# 지도
# VIBE
# 책
# 웹툰

# %% [markdown]
# ## 뉴스 타이틀 수집

# %%
res = req.get("https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EC%9E%A5%EB%A7%88")
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="장마 : 네이버 뉴스검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'장마\'의 네이버 뉴스검색 결과입니다."> <meta name="description" lang="ko" content="\'장마\'의 네이버 뉴스검색 결과입니다."> <title>장마 : 네이버 뉴스검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_220707.css"> <link rel="stylesheet" type="text/css" href="
# ...

# %%
soup = bs(res.text, "lxml")
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
data = soup.select(".news_tit")
data
# Out:
# [<a class="news_tit" href="https://www.ytn.co.kr/_ln/0101_202207100915553219" onclick="return goOtherCR(this, 'a=nws*h.tit&amp;r=1&amp;i=880000AF_000000000000000001762106&amp;g=052.0001762106&amp;u='+urlencode(this.href));" target="_blank" title='"北, 장마 피해로 9월까진 핵실험 안 할 것"'>"北, <mark>장마</mark> 피해로 9월까진 핵실험 안 할 것"</a>,
#  <a class="news_tit" href="http://www.sisamagazine.co.kr/news/articleView.html?idxno=453649" onclick="return goOtherCR(this, 'a=nws*b.tit&amp;r=6&amp;i=8818327c_000000000000000000190086&amp;g=5617.0000190086&amp;u='+urlencode(this.href));" target="_blank" title="월요일 오늘날씨, 전국 '60mm요란한 비' 서울날씨, 2022년 장마기간">월요일 오늘날씨, 전국 '60mm요란한 비' 서울날씨, 2022년 <mark>장마</mark>기간</a>,
# ...

# %%
for i in data:
    print(i.text)
# Out:
# "北, 장마 피해로 9월까진 핵실험 안 할 것"
# 월요일 오늘날씨, 전국 '60mm요란한 비' 서울날씨, 2022년 장마기간
# 이번 주 전국 장마 영향권…전력거래소 "안정적 전력수급 전망"
# 북한 13~14일 또 폭우…홍수경보 발령 등 장마대책 안간힘
# 장마·폭염 반복에… 날씨 관련 트윗 최근 320만건 달해
# [1일IT템] 14일에 뜨는 수퍼문… 장마에 못보나
# 마른 장마에 저수량 감소…광주시 "수돗물 아껴쓰세요"
# 반가운 장마
# 양구군, 장마철 오염물질 무단배출 특별 감시·단속
# [오늘날씨] 밤부터 비온다, 서울34도·대구35도 '2022년 장마기간'

# %%
res = req.get("https://map.naver.com/v5/search/%EC%B9%B4%ED%8E%98/place/1383307364?placePath=%3Fentry=pll%26from=nx%26fromNxList=true&c=14127573.1186506,4184138.9534907,14,0,0,0,dh")
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="ko">\n  <head>\n    <title>ë\x84¤ì\x9d´ë²\x84 ì§\x80ë\x8f\x84</title>\n    <meta charset="utf-8"/>\n    <meta name="Referrer" content="origin"/>\n    <meta http-equiv="Content-Script-Type" content="text/javascript"/>\n    <meta http-equiv="Content-Style-Type" content="text/css"/>\n    <meta http-equiv="x-ua-compatible" content="ie=edge"/>\n    <meta name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0"/>\n    <meta name="format-detection" content="telephone=no"/>\n    <meta name="description" content="ê³µê°\x84ì\x9d\x84 ê²\x80ì\x83\x89í\x95©ë\x8b\x88ë\x8b¤. ì\x83\x9dí\x99\x9cì\x9d\x84 ì\x97°ê²°í\x95©ë\x8b\x88ë\x8b¤. ì\x9e¥ì\x86\x8c, ë²\x84ì\x8a¤, ì§\x80í\x95\x98ì²\xa0, ë\x8f\x84ë¡\x9c ë\x93± ëª¨ë\x93\xa0 ê³µê°\x84ì\x9d\x98 ì\xa0\x95ë³´ë¥¼ í\x95\x98ë\x82\x98ì\x9d\x98 ê²\x80ì\x83\x89ì\x9c¼ë¡\x9c ì\x97°ê²°í\x95\x9c ì\x83\x88ë¡\x9cì\x9a´ ì§\x80ë\x8f\x84ë¥¼ ë§\x8cë\x82\x98ë³´ì\x84¸ì\x9a\x94.">\n    <meta name="goog
# ...

# %%
soup = bs(res.text, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <title>ë¤ì´ë² ì§ë</title>
# <meta charset="utf-8"/>
# <meta content="origin" name="Referrer"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="ê³µê°ì ê²ìí©ëë¤. ìíì ì°ê²°í©ëë¤. ì¥ì, ë²ì¤, ì§íì² , ëë¡ ë± ëª¨ë  ê³µê°ì ì ë³´ë¥¼ íëì ê²ìì¼ë¡ ì°ê²°í ìë¡ì´ ì§ëë¥¼ ë§ëë³´ì¸ì." name="description"/>
# <meta content="AO_6MCsaxSfiydw-JSF8cCpFrYPwZDiEo40pMwIwl7Q" name="google-site-verification"/>
# <meta content="website" property="og:type"/>
# <meta content="ë¤ì´ë² ì§ë" property="og:site_name"/>
# <meta content="ë¤ì´ë² ì§ë" property="og:title"/>
# ...

# %%
soup.select("#_title > span._3XamX")
# Out:
# []
