# %% [markdown]
# ### OCR(광학문자판독)
# - 이미지로 된 문자를 텍스트로 변환하는 작업
# - Tessaract API, 구글 OCR API, Naver OCR API 등을 사용
# - https://github.com/UB-Mannheim/tesseract/wiki
# - Additional language data

# %%
# 파이썬용 Tessaract API 설치
# !pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.9-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\smhrd\anaconda3\envs\deep\lib\site-packages (from pytesseract) (21.3)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\smhrd\anaconda3\envs\deep\lib\site-packages (from pytesseract) (9.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\smhrd\anaconda3\envs\deep\lib\site-packages (from packaging>=21.3->pytesseract) (3.0.4)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.9

# %%
# 설치 위치를 지정
import pytesseract
pytesseract.pytesseract.tesseract_cmd = \
r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# 이미지 불러오기
img = cv2.imread("./data/num.jfif")
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)

plt.xticks([])
plt.yticks([])
plt.imshow(img)
