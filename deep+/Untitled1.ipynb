# %%
import cv2
img_color = cv2.imread('./folder/plate.jpg')
img_gray = cv2.cvtColor(img_color, cv2.COLOR_BGR2GRAY)
ret, img_binary = cv2.threshold(img_gray, 127,255,0)
contours, hierarchy = cv2.findContours(img_binary, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

for cnt in contours:
    cv2.drawContours(img_color, [cnt], 0, (255,0,0), 3)
    
cv2.imshow("result", img_color)    
cv2.waitKey(0)

for cnt in contours:
    area = cv2.contourArea(cnt)
    print(area)
    
cv2.imshow("result", img_color)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 4.0
# 103.5
# 4.0
# 8.5
# 8.5
# 0.0
# 194.0
# 2.0
# 10.0
# 2.0
# 4.0
# 9.0
# 4.0
# 2.0
# 4.0
# 4.0
# 10.5
# 12.0
# 0.0
# 2.0
# 2.0
# 2.0
# 6.0
# 0.0
# 0.0
# 2.0
# 22.5
# 4.0
# 4.0
# 2.0
# 4.0
# 5.5
# 79.0
# 2.0
# 181.0
# 68.0
# 2.0
# 514.0
# 25.5
# 2.0
# 28.0
# 15.0
# 0.0
# 2.0
# 193.5
# 104.0
# 1016.0
# 787.0
# 2.0
# 1990.5
# 784.5
# 6.0
# 18.0
# 2.0
# 2.0
# 2.0
# 47.5
# 12.0
# 5.5
# 67.5
# 196.0
# 272.5
# 82.5
# 2.0
# 2.0
# 38.5
# 2.0
# 8.0
# 2.0
# 55.0
# 126.0
# 188.0
# 2.0
# 140.0
# 2.0
# 8.0
# 36.0
# 325.5
# 13.0
# 14.5
# 2.0
# 4.0
# 2.0
# 35716.5
# 13.0
# 2.0
# 2.0
# 0.0
# 2.0
# 7.0
# 0.0
# 0.0
# 0.0
# 2.0
# 31.5
# 42306.0
# 27.5
# 0.0
# 2.0
# 0.0
# 0.0
# 3.5
# 5.5
# 1397.0
# 2.0
# 0.0
# 25.0
# 8503.5
# 14.0
# 2410.0
# 72.5
# 72570.0
