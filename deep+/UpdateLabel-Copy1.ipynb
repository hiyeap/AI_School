# %%
import os
import pandas as pd
file_names=os.listdir('C:/Users/smhrd/Desktop/change/labels')

# %%
file_names[1]
# Out:
# 'ADB01TE193700903.txt'

# %%
text_file_path = 'C:/Users/smhrd/Desktop/change/labels/'+ file_names[21]
text_file_path
# Out:
# 'C:/Users/smhrd/Desktop/change/labels/ADB03EC198699975.txt'

# %%
text_file_path = 'C:/Users/smhrd/Desktop/change/labels/'+ file_names[0]
df = pd.read_csv(text_file_path, sep = ' ',header=None)
a = len(df)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13748\845747467.py in <module>
#       3 a = len(df)
#       4 df
# ----> 5 for i in a:
#       6     df.loc[i]
#
# TypeError: 'int' object is not iterable

# %%
k=0
for i in file_names:
    text_file_path = 'C:/Users/smhrd/Desktop/change/labels/'+ file_names[k]
    df = pd.read_csv(text_file_path, sep = ' ',header=None)
    if df.iloc[0,0]==1:
        df.iloc[0,0]=5
    if df.iloc[1,0]==1:
        df.iloc[1,0]=5
    if df.iloc[2,0]==1:
        df.iloc[2,0]=5
    if df.iloc[3,0]==1:
        df.iloc[3,0]=5
    if df.iloc[4,0]==2:
        df.iloc[4,0]=4
    if df.iloc[5,0]==0:
        df.iloc[5,0]=3
    print(df.iloc[0,0])
    print(df.iloc[1,0])
    print(df.iloc[2,0])
    print(df.iloc[3,0])
    print(df.iloc[4,0])
    print(df.iloc[5,0])
    df.to_csv(file_names[k], index = False, sep = ' ', header=False)
    k = k+1
# Out:
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 2
# 5
# 1
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 2
# 2
# 2
# 2
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# 4
# 3
# 5
# 5
# 5
# 5
# ...

# %%
len(df)
